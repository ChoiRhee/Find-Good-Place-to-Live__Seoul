# %%
import geopandas as gpd
import pandas as pd

# %%
seoul = gpd.read_file('Data/processed_soul.shp', encoding='utf-8')
seoul
# Out:
#        EMD_CD EMD_NM  SGG_OID COL_ADM_SE   GID SI_NAME  \
# 0    11290129  보문동7가        7      11290  5222     성북구
# 1    11290103    돈암동        8      11290  5223     성북구
# 2    11290139    석관동        9      11290  5224     성북구
# 3    11290114  삼선동4가       22      11290  5225     성북구
# 4    11290117  동선동2가       29      11290  5232     성북구
# ..        ...    ...      ...        ...   ...     ...
# 462  11230102    용두동      705      11230  2658    동대문구
# 463  11230107   청량리동      376      11230  2659    동대문구
# 464  11410112    대현동     1714      11410  2660    서대문구
# 465  11110157    인의동      348      11110  2661     종로구
# 466  11110150    훈정동      332      11110  2662     종로구
#
#                                               geometry
# 0    POLYGON ((957864.444 1953662.735, 957878.870 1...
# 1    POLYGON ((956352.458 1955412.808, 956340.774 1...
# 2    POLYGON ((961229.416 1956099.120, 961229.075 1...
# 3    POLYGON ((957329.114 1954659.435, 957325.653 1...
# ...

# %%
seoul.drop('SGG_OID', axis=1, inplace=True)
seoul.drop('COL_ADM_SE', axis=1, inplace=True)
seoul.drop('GID', axis=1, inplace=True)

# %%
#bab_cnt = pd.read_csv('Data/Tableau_Data/BaB_cnt_cal_pop.csv')
#bab_cnt

# %%
seoul.to_file("Data/Tableau_Data/processed_soul.shp", encoding='utf-8')
